# %%
from sqlalchemy.orm import sessionmaker
from sqlalchemy import create_engine


engine = create_engine(f"sqlite:///'forex_news_bot.db'", echo=False, future=True)
SessionLocal = sessionmaker(autocommit=False, autoflush=False, bind=engine, future=True)

# %%
from sqlalchemy.sql import text, select, func
import pandas as pd

# %%
sess = SessionLocal()

# %%
rows = sess.execute(text("SELECT * FROM ranges")).fetchall()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\user\anaconda3\envs\algo\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File c:\Users\user\anaconda3\envs\algo\Lib\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# OperationalError: no such table: ranges
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df = pd.read_sql_query(sql="SELECT * FROM events", con=sess.bind)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\user\anaconda3\envs\algo\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File c:\Users\user\anaconda3\envs\algo\Lib\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# OperationalError: no such table: events
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
with SessionLocal() as sess:
    sess.execute(text(f"SELECT * FROM ranges"))
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\user\anaconda3\envs\algo\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File c:\Users\user\anaconda3\envs\algo\Lib\site-packages\sqlalchemy\engine\default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# OperationalError: no such table: ranges
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
max_weight_events_by_time = past_events.groupby("rounded_time")[["weights", "main_event"]].apply(
    lambda x: get_max_weight_event(x, mie_col="main_event")
)
